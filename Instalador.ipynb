# %% [markdown]
# 1. Instalar node js
#     - Ingresa a esta url https://nodejs.org/es/download
#     - instalas donde te indica la imgen que se encuentra en .. puppeteer\Referencias\node.png
#     - luego das en el archivo descargado y sigue los paso que te indican

# %% [markdown]
# 2. En el caso de no tener python ejcuta el siguiente comando
#     - winget install Python.Python.3
#     o ve a la tienda y instalalo desde ahi
#     https://apps.microsoft.com/detail/9PNRBTZXMB4Z?hl=en-us&gl=US&ocid=pdpshare

# %% [markdown]
# Ejecuta la siguiente celda para instalar los requierimientos

# %%
import sys
# !{sys.executable} -m pip install -r requirements.txt

# %% [markdown]
# 3. Llena el archivo informacion.xlsx con los casos a ejecutar

# %% [markdown]
# Abre CMD en la ruta donde este el desarrollo y para ejecutar el programa usa node index.js
